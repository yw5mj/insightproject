# %% [markdown]
# # General rating distributions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('cleandata/allbeers.csv',';')

# %%
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=18)
plt.hist(df.rating,bins=15)
plt.xlabel('all ratings', fontsize=18)
# Out:
# Text(0.5, 0, 'all ratings')

# %%
plt.hist(df.beer_id.value_counts(),bins=range(0,5000,100),log=True)
plt.xlabel('Number of ratings for each beer',fontsize=18)
# Out:
# Text(0.5, 0, 'Number of ratings for each beer')

# %%
sns.heatmap(df[['rating','look','smell','taste','feel']].corr(),cmap="YlGnBu" )

# %% [raw]
# taste is important, we should do something about it later

# %%
reviews=df[['beer_id', 'review']].dropna()
plt.hist(reviews.beer_id.value_counts(),bins=range(0,5000,100),log=True)
plt.xlabel('Number of reviews for each beer',fontsize=18)
# Out:
# Text(0.5, 0, 'Number of reviews for each beer')

# %%
plt.hist(reviews.review.apply(lambda x:len(x.split(' '))),bins=range(0,500,10))
plt.xlabel('Number of words for each review',fontsize=18)
print('mean words in a review',reviews.review.apply(lambda x:len(x.split(' '))).mean())
# Out:
# mean words in a review 118.11594853423712
